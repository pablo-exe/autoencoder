# %% [markdown]
# #Visualizacion de los datos

# %%
from keras.datasets import mnist
import matplotlib.pyplot as plt

(X_train, y_train), (X_test, y_test) = mnist.load_data()

num_train_images = X_train.shape[0]
num_test_images = X_test.shape[0]
image_height = X_train.shape[1]
image_width = X_train.shape [2]

print("Shape: " + str(X_train.shape))
print("Training images: " + str(num_train_images))
print("Image height: " + str(image_height))
print("Image width: " + str(image_width))
# Out:
# Shape: (60000, 28, 28)
# Training images: 60000
# Image height: 28
# Image width: 28

# %%
def plot(X):
    fig, axs = plt.subplots(1,12, figsize=(17,6))
    for i in range(12):
        axs[i].imshow(X[i], cmap = plt.get_cmap('gray'))
        axs[i].axis('off')
    plt.show()
    
X = X_test[:12,:]
plot(X)

# %% [markdown]
# #Data Cleaning

# %%
from keras.models import Sequential
from keras.layers import Dense

# Dense layer shape
X_train = X_train.reshape(num_train_images,image_height*image_width)  
X_test = X_test.reshape(num_test_images,image_height*image_width)
X_train = X_train/255
X_test = X_test/255

# %% [markdown]
# #Autoencoder monocapa

# %% [markdown]
# Autoencoder de 8 neuronas

# %%
model = Sequential()

#Primera capa
model.add(Dense(8,input_dim=image_height*image_width, 
                activation='relu'))   # 28 * 28 = 784
#Segunda capa
model.add(Dense(image_height*image_width, activation='relu'))

model.summary()

model.compile(loss='mean_squared_error', optimizer='adam',
              metrics=['accuracy'])#Metrics accuracy no es adecuado, tendriamos que poner mae(v.a de la resta) o msd(v.a ** 2)(estas serian las metricas adecuadas)
                                   #accuracy ve cuantas ha acertado de cada muestra.
model.fit(X_train, X_train, validation_data=(X_test, X_test),
          epochs=10, batch_size=512, verbose=0)#Meto x_train y espero x_train de nuevo, aprende viendo la diferencia entre lo que entra y lo q sale
X = []
for i in range(12):
    X.append(model.predict(X_test[i,:].
              reshape(1,image_height*image_width)).
              reshape(image_height,image_width))
plot(X)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 8)                 6280
#
#  dense_5 (Dense)             (None, 784)               7056
#
# ...
# Total params: 13,336
# Trainable params: 13,336
# Non-trainable params: 0
# _________________________________________________________________
# ...
# 1/1 [==============================] - 0s 15ms/step

# %% [markdown]
# Autoencoder de 24 neuronas

# %%
model = Sequential()

#Primera capa
model.add(Dense(24,input_dim=image_height*image_width, 
                activation='relu'))   # 28 * 28 = 784
#Segunda capa
model.add(Dense(image_height*image_width, activation='relu'))

model.summary()

model.compile(loss='mean_squared_error', optimizer='adam',
              metrics=['accuracy'])#Metrics accuracy no es adecuado, tendriamos que poner mae(v.a de la resta) o msd(v.a ** 2)(estas serian las metricas adecuadas)
                                   #accuracy ve cuantas ha acertado de cada muestra.
model.fit(X_train, X_train, validation_data=(X_test, X_test),
          epochs=10, batch_size=512, verbose=0)#Meto x_train y espero x_train de nuevo, aprende viendo la diferencia entre lo que entra y lo q sale
X = []
for i in range(12):
    X.append(model.predict(X_test[i,:].
              reshape(1,image_height*image_width)).
              reshape(image_height,image_width))
plot(X)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 24)                18840
#
#  dense_7 (Dense)             (None, 784)               19600
#
# ...
# Total params: 38,440
# Trainable params: 38,440
# Non-trainable params: 0
# _________________________________________________________________
# ...
# 1/1 [==============================] - 0s 15ms/step

# %% [markdown]
# Autoencoder de 40 neuronas

# %%
model = Sequential()

#Primera capa
model.add(Dense(40,input_dim=image_height*image_width, 
                activation='relu'))   # 28 * 28 = 784
#Segunda capa
model.add(Dense(image_height*image_width, activation='relu'))

model.summary()

model.compile(loss='mean_squared_error', optimizer='adam',
              metrics=['accuracy'])#Metrics accuracy no es adecuado, tendriamos que poner mae(v.a de la resta) o msd(v.a ** 2)(estas serian las metricas adecuadas)
                                   #accuracy ve cuantas ha acertado de cada muestra.
model.fit(X_train, X_train, validation_data=(X_test, X_test),
          epochs=10, batch_size=512, verbose=0)#Meto x_train y espero x_train de nuevo, aprende viendo la diferencia entre lo que entra y lo q sale
X = []
for i in range(12):
    X.append(model.predict(X_test[i,:].
              reshape(1,image_height*image_width)).
              reshape(image_height,image_width))
plot(X)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_8 (Dense)             (None, 40)                31400
#
#  dense_9 (Dense)             (None, 784)               32144
#
# ...
# Total params: 63,544
# Trainable params: 63,544
# Non-trainable params: 0
# _________________________________________________________________
# ...
# 1/1 [==============================] - 0s 16ms/step

# %% [markdown]
# Autoencoder de 100 neuronas

# %%
model = Sequential()

#Primera capa
model.add(Dense(100,input_dim=image_height*image_width, 
                activation='relu'))   # 28 * 28 = 784
#Segunda capa
model.add(Dense(image_height*image_width, activation='relu'))

model.summary()

model.compile(loss='mean_squared_error', optimizer='adam',
              metrics=['accuracy'])#Metrics accuracy no es adecuado, tendriamos que poner mae(v.a de la resta) o msd(v.a ** 2)(estas serian las metricas adecuadas)
                                   #accuracy ve cuantas ha acertado de cada muestra.
model.fit(X_train, X_train, validation_data=(X_test, X_test),
          epochs=10, batch_size=512, verbose=0)#Meto x_train y espero x_train de nuevo, aprende viendo la diferencia entre lo que entra y lo q sale
X = []
for i in range(12):
    X.append(model.predict(X_test[i,:].
              reshape(1,image_height*image_width)).
              reshape(image_height,image_width))
plot(X)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_10 (Dense)            (None, 100)               78500
#
#  dense_11 (Dense)            (None, 784)               79184
#
# ...
# Total params: 157,684
# Trainable params: 157,684
# Non-trainable params: 0
# _________________________________________________________________
# ...
# 1/1 [==============================] - 0s 19ms/step

# %% [markdown]
# #------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #Autoencoder multicapa

# %%
def make_multi_layer_model(num_inner_neurons, num_outers_neurons):
    model = Sequential()
    model.add(Dense(num_outers_neurons,input_dim=image_height*image_width, 
                    activation='relu'))
    model.add(Dense(num_inner_neurons,activation='relu'))
    model.add(Dense(num_outers_neurons,activation='relu'))
    model.add(Dense(image_height*image_width, activation='relu'))
    model.summary()
    return model

def multi_layer_autoencoder(num_inner_neurons, num_outers_neurons):
    model = make_multi_layer_model(num_inner_neurons, num_outers_neurons)

    model.compile(loss='mean_squared_error', optimizer='adam',
                  metrics=['accuracy'])
    model.fit(X_train, X_train, validation_data=(X_test, X_test),
              epochs=20, batch_size=512, verbose=0)
    X = []
    for i in range(12):
        X.append(model.predict(X_test[i,:].
                 reshape(1,image_height*image_width)).
                 reshape(image_height,image_width))
    plot(X)
    
for num_inner_neurons, num_outers_neurons in zip([8,24,40],[16,40,100]):
    multi_layer_autoencoder(num_inner_neurons, num_outers_neurons)
#En este ejemplo , no rentaria meter un autoencoder de 3 capas ocultas, ya que obtenemos resuktados similares(no mejora el anterior)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 16)                12560
#
#  dense_13 (Dense)            (None, 8)                 136
#
#  dense_14 (Dense)            (None, 16)                144
#
#  dense_15 (Dense)            (None, 784)               13328
#
# ...
# Total params: 26,168
# Trainable params: 26,168
# Non-trainable params: 0
# _________________________________________________________________
# ...
# 1/1 [==============================] - 0s 13ms/step
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_16 (Dense)            (None, 40)                31400
#
#  dense_17 (Dense)            (None, 24)                984
#
#  dense_18 (Dense)            (None, 40)                1000
#
# ...

# %% [markdown]
# #Autoencoders convolucionales

# %%
from keras.layers import Reshape, Conv2D, MaxPooling2D, Conv2DTranspose,Flatten, Dense
from keras.datasets import mnist
from keras.models import Sequential

(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train.reshape(X_train.shape[0],#numero de muestra 1a dim
                          X_train.shape[1],X_train.shape[2],1)#2 altura y 3 anchura
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],X_test.shape[2],1)
X_train = X_train/255
X_test = X_test/255

# %%
model = Sequential()
model.add(Conv2D(16, (3,3), input_shape=(28, 28,1),
          activation='relu',padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2),name='pool1'))#MaxPooling reduce tamaño imagenes
model.add(Conv2D(8, (3,3), activation='relu',padding='same'))#Crea la capa convolucional de los filtros
model.add(MaxPooling2D(pool_size=(2, 2),name='pool2'))
model.add(Conv2D(4, (3,3), activation='relu',padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2),name='pool3'))
model.add(Flatten(name='flatten'))#convierte en plana, para capas densas(solo se les puede pasar en plano) OMITIBLE
model.add(Reshape((3,3,4)))#la dimensiona OMITIBLE
model.add(Conv2DTranspose(4, kernel_size = (5,5), activation='relu'))#Hace la convolucional pero al reves
model.add(Conv2DTranspose(8, kernel_size = (8,8), activation='relu'))
model.add(Conv2DTranspose(16, kernel_size = (15,15), activation='relu'))
model.add(Conv2D(1, (3, 3), activation='relu',padding='same'))#Tengo 16 filtros por lo que tengo 16 mapas de activacion, pero yo espero de resultado una unica imagen para contrastar con la entrada por eso el Conv2D(1,.....)
model.summary()

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, X_train, validation_data=(X_test, X_test),epochs=10,
          batch_size=256, verbose=1)
X = []
for i in range(12):
    X.append(model.predict(X_test[i,:].reshape(1,28,28,1)).reshape(28,28))
plot(X)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_8 (Conv2D)           (None, 28, 28, 16)        160
#
#  pool1 (MaxPooling2D)        (None, 14, 14, 16)        0
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 8)         1160
#
#  pool2 (MaxPooling2D)        (None, 7, 7, 8)           0
#
#  conv2d_10 (Conv2D)          (None, 7, 7, 4)           292
#
#  pool3 (MaxPooling2D)        (None, 3, 3, 4)           0
#
#  flatten (Flatten)           (None, 36)                0
#
#  reshape_2 (Reshape)         (None, 3, 3, 4)           0
#
#  conv2d_transpose_6 (Conv2DT  (None, 7, 7, 4)          404
#  ranspose)
#
#  conv2d_transpose_7 (Conv2DT  (None, 14, 14, 8)        2056
#  ranspose)
#
#  conv2d_transpose_8 (Conv2DT  (None, 28, 28, 16)       28816
#  ranspose)
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 1)         145
#
# ...
# Total params: 33,033
# Trainable params: 33,033
# ...

# %% [markdown]
# Creamos un modelo como el anterior pero con 2 neuronas en el bottleneck

# %%
model = Sequential()
model.add(Conv2D(16, (3,3), input_shape=(28, 28,1),
          activation='relu',padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2),name='pool1'))
model.add(Conv2D(8, (3,3), activation='relu',padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2),name='pool2'))
model.add(Conv2D(4, (3,3), activation='relu',padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2),name='pool3'))
model.add(Flatten(name='flatten'))

model.add(Dense(2, input_dim = 3 * 3 * 4, activation= 'relu'))
model.add(Dense(3 * 3 * 4, activation= 'relu'))

model.add(Reshape((3,3,4)))
model.add(Conv2DTranspose(4, kernel_size = (5,5), activation='relu'))
model.add(Conv2DTranspose(8, kernel_size = (8,8), activation='relu'))
model.add(Conv2DTranspose(16, kernel_size = (15,15), activation='relu'))
model.add(Conv2D(1, (3, 3), activation='relu',padding='same'))#Tengo 16 filtros por lo que tengo 16 mapas de activacion, pero yo espero de resultado una unica imagen para contrastar con la entrada por eso el Conv2D(1,.....)
model.summary()

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, X_train, validation_data=(X_test, X_test),epochs=10,
          batch_size=256, verbose=1)
X = []
for i in range(12):
    X.append(model.predict(X_test[i,:].reshape(1,28,28,1)).reshape(28,28))
plot(X)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_16 (Conv2D)          (None, 28, 28, 16)        160
#
#  pool1 (MaxPooling2D)        (None, 14, 14, 16)        0
#
#  conv2d_17 (Conv2D)          (None, 14, 14, 8)         1160
#
#  pool2 (MaxPooling2D)        (None, 7, 7, 8)           0
#
#  conv2d_18 (Conv2D)          (None, 7, 7, 4)           292
#
#  pool3 (MaxPooling2D)        (None, 3, 3, 4)           0
#
#  flatten (Flatten)           (None, 36)                0
#
#  dense_26 (Dense)            (None, 2)                 74
#
#  dense_27 (Dense)            (None, 36)                108
#
#  reshape_4 (Reshape)         (None, 3, 3, 4)           0
#
#  conv2d_transpose_12 (Conv2D  (None, 7, 7, 4)          404
#  Transpose)
#
#  conv2d_transpose_13 (Conv2D  (None, 14, 14, 8)        2056
#  Transpose)
#
#  conv2d_transpose_14 (Conv2D  (None, 28, 28, 16)       28816
# ...

# %% [markdown]
# #Visualizacion del espacio multidimensional

# %%
import matplotlib.pyplot as plt
from keras.models import Model

LAYER_2_NEURONS = 7
model_to_draw2D = Model(inputs=model.input,outputs=model.layers[LAYER_2_NEURONS].output)
intermediate_output = model_to_draw2D.predict(X_test)
print(intermediate_output.shape)
print(y_test.shape)

print(intermediate_output)
print(y_test)

plt.figure(figsize=(10,10))
for i in range(10):
    plt.scatter(intermediate_output[y_test==i,0], intermediate_output[y_test==i,1], marker='o', label= format(i))

plt.xlabel('Neuron 1', fontsize=15)
plt.ylabel('Neuron 2', fontsize=15)
plt.legend(prop={'size':14}); plt.grid(); 
plt.grid(True)
plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step
# (10000, 2)
# (10000,)
# [[0.73810893 3.243266  ]
#  [2.5957983  0.2638518 ]
#  [0.81795436 0.3885204 ]
#  ...
#  [1.3354764  2.2318366 ]
#  [2.1121316  1.3479288 ]
#  [3.3868284  2.3871353 ]]
# [7 2 1 ... 4 5 6]

# %% [markdown]
# Visualizacion en 3D

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
num_train_images = X_train.shape[0]
num_test_images = X_test.shape[0]
image_height = X_train.shape[1]
image_width = X_train.shape [2]

X_train = X_train.reshape(num_train_images,image_height*image_width)  
X_test = X_test.reshape(num_test_images,image_height*image_width)
X_train = X_train/255
X_test = X_test/255

model3D = Sequential() 
model3D.add(Dense(64, input_dim=image_height*image_width, activation='relu'))
model3D.add(Dense(3,activation='relu'))
model3D.add(Dense(64,activation='relu'))
model3D.add(Dense(image_height*image_width, activation='relu'))
model3D.summary()

model3D.compile(loss='mean_squared_error', optimizer='adam',metrics=['accuracy'])
model3D.fit(X_train, X_train, validation_data=(X_test, X_test),epochs=20,
            batch_size=512, verbose=0)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_28 (Dense)            (None, 64)                50240
#
#  dense_29 (Dense)            (None, 3)                 195
#
#  dense_30 (Dense)            (None, 64)                256
#
#  dense_31 (Dense)            (None, 784)               50960
#
# ...
# Total params: 101,651
# Trainable params: 101,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  

LAYER_3_NEURONS = 1
model_to_draw3D = Model(inputs=model3D.input,
                        outputs=model3D.layers[LAYER_3_NEURONS].output)
int_out = model_to_draw3D.predict(X_test)
print(int_out.shape)
# Out:
# 313/313 [==============================] - 0s 1ms/step
# (10000, 3)

# %%
fig = plt.figure(figsize=(7, 7))
axs = Axes3D(fig, elev=10, azim=-70)

for i in range(10):
    axs.scatter(int_out[y_test==i,0], int_out[y_test==i,1], 
                int_out[y_test==i,2], marker='.')
axs.set_xlabel('Neuron 1', fontsize=18)
axs.set_ylabel('Neuron 2', fontsize=18)
axs.set_zlabel('Neuron 3', fontsize=18) 
axs.grid(); 
plt.show()
